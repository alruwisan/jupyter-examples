# %% [markdown]
# # Setup configuration for Using Fabric Testbed via FABlib API
#
# The following notebook can be used to configure your Jupyter environment.  The product of running this notebook are the following:
#
# - `fabric_rc`:  File used to configure a FABlib application.
# - `fabric_bastion_key`: Fabric Bastion key pair. In order to minimize security incidents on FABRIC, access to VMs and other resources administered by users is controlled using a bastion host. You will need to set up an ssh keypair that will be used to jump through the bastion host to your VMs and other resources. This keypair is unique to you and is only used to set up ssh proxy connections through the bastion host to your FABRIC resources. More information about how to access your experiment through the bastion host can be found [here](https://learn.fabric-testbed.net/knowledge-base/logging-into-fabric-vms/).
# - `slice_key` and `slice_key.pub`: Sliver Key pair.
# - `ssh_config`: File used to ssh from from a terminal to FABRIC VM by jumping through the FABRIC bastion host.

# %% [markdown]
# ## Set Project ID and generate the configuration
#
# Edit the following cell by entering your Project ID for the FABRIC Project to use in your Jupyter container.
#
# - The Project ID can be from any of your projects. The ID can be found in the 'Basic Info' tab for each of the [projects](https://portal.fabric-testbed.net/experiments#projects) in the FABRIC portal.

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Update this line to specify your project id
project_id = "926daf56-3ad4-44c1-82f0-9221e04ea3d9"

# Uncomment the line below if using 'FABRIC Tutorials' Project
#project_id="a7818636-1fa1-4e77-bb03-d171598b0862"

fablib = fablib_manager(project_id=project_id)
# Out:
# User: me348264@ucf.edu bastion keys do not exist or are expired.
# Please call `verify_and_configure` to renew your bastion keys!
# Sliver Keys saved at location: /home/ubuntu/work/fabric_config/slice_key
# Configuration is valid

# %% [markdown]
# ## Display the configuration

# %%
fablib.show_config();
# Out:
# <style type="text/css">
# #T_5b8a0 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5b8a0 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5b8a0 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_5b8a0_row0_col0, #T_5b8a0_row0_col1, #T_5b8a0_row1_col0, #T_5b8a0_row1_col1, #T_5b8a0_row2_col0, #T_5b8a0_row2_col1, #T_5b8a0_row3_col0, #T_5b8a0_row3_col1, #T_5b8a0_row4_col0, #T_5b8a0_row4_col1, #T_5b8a0_row5_col0, #T_5b8a0_row5_col1, #T_5b8a0_row6_col0, #T_5b8a0_row6_col1, #T_5b8a0_row7_col0, #T_5b8a0_row7_col1, #T_5b8a0_row8_col0, #T_5b8a0_row8_col1, #T_5b8a0_row9_col0, #T_5b8a0_row9_col1, #T_5b8a0_row10_col0, #T_5b8a0_row10_col1, #T_5b8a0_row11_col0, #T_5b8a0_row11_col1, #T_5b8a0_row12_col0, #T_5b8a0_row12_col1, #T_5b8a0_row13_col0, #T_5b8a0_row13_col1, #T_5b8a0_row14_col0, #T_5b8a0_row14_col1, #T_5b8a0_row15_col0, #T_5b8a0_row15_col1, #T_5b8a0_row16_col0, #T_5b8a0_row16_col1, #T_5b8a0_row17_col0, #T_5b8a0_row17_col1, #T_5b8a0_row18_col0, #T_5b8a0_row18_col1, #T_5b8a0_row19_col0, #T_5b8a0_row19_col1, #T_5b8a0_row20_col0, #T_5b8a0_row20_col1, #T_5b8a0_row21_col0, #T_5b8a0_row21_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5b8a0">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b8a0_row0_col0" class="data row0 col0" >Project ID</td>
#       <td id="T_5b8a0_row0_col1" class="data row0 col1" >926daf56-3ad4-44c1-82f0-9221e04ea3d9</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row1_col0" class="data row1 col0" >Log Level</td>
#       <td id="T_5b8a0_row1_col1" class="data row1 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row2_col0" class="data row2 col0" >Log File</td>
#       <td id="T_5b8a0_row2_col1" class="data row2 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row3_col0" class="data row3 col0" >Log Propagate</td>
#       <td id="T_5b8a0_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row4_col0" class="data row4 col0" >Data directory</td>
#       <td id="T_5b8a0_row4_col1" class="data row4 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row5_col0" class="data row5 col0" >Orchestrator</td>
#       <td id="T_5b8a0_row5_col1" class="data row5 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row6_col0" class="data row6 col0" >Credential Manager</td>
#       <td id="T_5b8a0_row6_col1" class="data row6 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row7_col0" class="data row7 col0" >Core API</td>
#       <td id="T_5b8a0_row7_col1" class="data row7 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row8_col0" class="data row8 col0" >Artifact Manager</td>
#       <td id="T_5b8a0_row8_col1" class="data row8 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row9_col0" class="data row9 col0" >CEPH Manager</td>
#       <td id="T_5b8a0_row9_col1" class="data row9 col1" >23.134.232.211</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row10_col0" class="data row10 col0" >Token File</td>
#       <td id="T_5b8a0_row10_col1" class="data row10 col1" >/home/ubuntu/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row11_col0" class="data row11 col0" >Bastion Host</td>
#       <td id="T_5b8a0_row11_col1" class="data row11 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row12_col0" class="data row12 col0" >Bastion Private Key File</td>
#       <td id="T_5b8a0_row12_col1" class="data row12 col1" >/home/ubuntu/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_5b8a0_row13_col1" class="data row13 col1" >1.9.6</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row14_col0" class="data row14 col0" >Slice Public Key File</td>
#       <td id="T_5b8a0_row14_col1" class="data row14 col1" >/home/ubuntu/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row15_col0" class="data row15 col0" >Slice Private Key File</td>
#       <td id="T_5b8a0_row15_col1" class="data row15 col1" >/home/ubuntu/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row16_col0" class="data row16 col0" >Sites to avoid</td>
#       <td id="T_5b8a0_row16_col1" class="data row16 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row17_col0" class="data row17 col0" >SSH Command Line</td>
#       <td id="T_5b8a0_row17_col1" class="data row17 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/ubuntu/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row18_col0" class="data row18 col0" >Bastion SSH Config File</td>
#       <td id="T_5b8a0_row18_col1" class="data row18 col1" >/home/ubuntu/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row19_col0" class="data row19 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_5b8a0_row19_col1" class="data row19 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row20_col0" class="data row20 col0" >Project Name</td>
#       <td id="T_5b8a0_row20_col1" class="data row20 col1" >Multipath TCP traffic load-balancer</td>
#     </tr>
#     <tr>
#       <td id="T_5b8a0_row21_col0" class="data row21 col0" >Bastion Username</td>
#       <td id="T_5b8a0_row21_col1" class="data row21 col1" >me348264_0000356733</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Validate the configuration;
# - Checks the validity of the bastion keys and regenerates them if they are expired
# - Generates Sliver keys if they do not exist already

# %%
fablib.verify_and_configure()
# Out:
# User: me348264@ucf.edu bastion keys do not exist or are expired.
# Bastion Key saved at location: /home/ubuntu/work/fabric_config/fabric_bastion_key
# Configuration is valid
# Please save the config!

# %% [markdown]
# ## Save the configuration for subsequent use

# %%
fablib.save_config()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fablib.save_config()
#
# File ~/fabric-notebook/.venv/lib/python3.12/site-packages/fabrictestbed_extensions/fablib/config/config.py:853, in Config.save_config(self)
#     849 def save_config(self):
#     850     """
#     851     Write the configuration file.
#     852     """
# --> 853     if self.config_file_path is None:
#     854         print("Config file path not set!")
#     855         return
#
# AttributeError: 'FablibManager' object has no attribute 'config_file_path'
